# %% [markdown]
# # Create test set
#
# In the file `explore_data.ipynb`, I found that a token cutoff of 3000 had over 95% of all tokens and articles. I also found that a cutoff of 30% symbol tokens captures about 90% of tokens and articles. In order to have a test set that is not to onerous to produce or too poor quality to recover I am going to combine both of these metrics

# %%
import pandas as pd
import tiktoken
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import time  # Make sure to import the time module
import shutil
import PyPDF2

from helper_functions import identify_file, find_pdf_path, extract_pages_from_pdf, process_pdfs


from dotenv import load_dotenv, find_dotenv
load_dotenv()

directory = './data/ncse_text_chunks'

dev_transcripts = 'data/dev_data_transcript'

dev_gpt4_results = 'data/dev_data_gpt-4-turbo-preview'
dev_gpt3_results = 'data/dev_data_gpt-3.5-turbo'

image_path = os.getenv("image_path")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 11
#       8 import shutil
#       9 import PyPDF2
# ---> 11 from helper_functions import identify_file, find_pdf_path, extract_pages_from_pdf, process_pdfs
#      14 from dotenv import load_dotenv, find_dotenv
#      15 load_dotenv()
#
# ModuleNotFoundError: No module named 'helper_functions'

# %% [markdown]
# Load the files individually filtering to ensure only the values valid for testing are included.

# %%
page_list = pd.read_parquet('data/periodicals_page.parquet')

periodicals_issue = pd.read_parquet('data/periodicals_issue.parquet')

periodicals_publication = pd.read_parquet('data/periodicals_publication.parquet')

# %%
page_info = page_list.merge(
    periodicals_issue[['id', 'publication_id', 'issue_date']].rename(columns = {'id':'issue_id'}), on = 'issue_id'
).merge(
   periodicals_publication[['id', 'slug', 'title']].rename(columns = {'id':'publication_id'}), on='publication_id' 
)

page_info
# Out:
#            id  height  number  \
# 0      170269    2270       6
# 1      170270    2267       7
# 2      170271    2268       8
# 3      170264    2355       1
# 4      170265    2275       2
# ...       ...     ...     ...
# 97694  153495    1433      72
# 97695  153496    1433      73
# 97696  153497    1433      74
# 97697  153498    1433      75
# 97698  153499    1433      76
#
#                                                    image  width  issue_id  \
# 0      periodicals/101-NS5-1842-10-29-PG001-SINGLE/Pg...   1579      5747
# 1      periodicals/101-NS5-1842-10-29-PG001-SINGLE/Pg...   1583      5747
# 2      periodicals/101-NS5-1842-10-29-PG001-SINGLE/Pg...   1583      5747
# 3      periodicals/101-NS5-1842-10-29-PG001-SINGLE/Pg...   1619      5747
# 4      periodicals/101-NS5-1842-10-29-PG001-SINGLE/Pg...   1583      5747
# ...                                                  ...    ...       ...
# 97694  periodicals/099-TEC-1890-04-01-001-SINGLE/Pg07...    922      4349
# 97695  periodicals/099-TEC-1890-04-01-001-SINGLE/Pg07...    922      4349
# 97696  periodicals/099-TEC-1890-04-01-001-SINGLE/Pg07...    922      4349
# 97697  periodicals/099-TEC-1890-04-01-001-SINGLE/Pg07...    922      4349
# 97698  periodicals/099-TEC-1890-04-01-001-SINGLE/Pg07...    922      4349
#
#        article_count  label  publication_id  issue_date slug  \
# 0                  9      6              27  1842-10-29   ns
# 1                 13      7              27  1842-10-29   ns
# 2                 14      8              27  1842-10-29   ns
# 3                 18  unpag              27  1842-10-29   ns
# 4                  7      2              27  1842-10-29   ns
# ...              ...    ...             ...         ...  ...
# 97694              1    434              26  1890-04-01   pc
# 97695              1    435              26  1890-04-01   pc
# 97696              2    436              26  1890-04-01   pc
# 97697              2    iii              26  1890-04-01   pc
# 97698              2     iv              26  1890-04-01   pc
#
#                                   title
# 0             Northern Star (1837-1852)
# 1             Northern Star (1837-1852)
# 2             Northern Star (1837-1852)
# 3             Northern Star (1837-1852)
# 4             Northern Star (1837-1852)
# ...                                 ...
# 97694  Publishers’ Circular (1880-1890)
# 97695  Publishers’ Circular (1880-1890)
# 97696  Publishers’ Circular (1880-1890)
# 97697  Publishers’ Circular (1880-1890)
# 97698  Publishers’ Circular (1880-1890)
#
# [97699 rows x 12 columns]

# %%
np.random.seed(1842)
test_set = page_info.groupby('title').sample(10)
# Out:
#            id  height  number  \
# 73538   92283    1240      67
# 73723   92889    1222      29
# 75301   94900    1231      24
# 71257   90939    1244      25
# 75831   95438    1245      55
# 73888   93132    1243      53
# 72679   93872    1241      71
# 71970   92552    1228       4
# 76257   95935    1242      49
# 74645   94098    1246      15
# 28889   97484    1686       6
# 40668  109316    1801      27
# 19698   81807    1527      14
# 25547   88294    1567      17
# 21548   86158    1477      28
# 32564  101277    1634      22
# 29714   98138    1801      16
# 20274   82211    1422      10
# 30091   98463    1801       5
# 25290   88027    1714      14
# 68680  120313    1476       6
# 42617   90865    1433       8
# 62636  113078    1518      52
# 43445  122756    1276      41
# 60469  110716    1388      43
# 57984  134289    1243       7
# 65750  116503    1243      48
# 64323  115145    1113       7
# 65845  116589    1258      52
# 42953  134677    1257      24
# 83     172649    2217       2
# 511    164857    1922      16
# 13343  161653    2271       2
# 10028  168775    2184       8
# 2283   166622    2244       7
# 16808  163774    2142       4
# 7104   170794    2276       3
# 17057  164063    2182       5
# 7979   172350    2215       7
# 3694   173572    2228       5
# 84734  146647    1441      56
# 89162  150954    1477      59
# 90766  152556    1407      68
# 90593  152432    1433       5
# 78049  138199    1442      13
# 86135  147995    1423     177
# 96773  158702    1553     123
# 79661  140248    1447      50
# 86238  148100    1423     271
# 97470  146368    1475      78
# 71018  160647    1776       1
# 69724  158990    1332       3
# 70038  159435    1320       2
# 70337  159895    1948      10
# 69683  158967    1363       8
# 69736  158984    1332      13
# 69183  158905    1319       4
# 69151   96780    1839       1
# 70284  159771    1342       2
# 70058  159395    2294      10
#
#                                                    image  width  issue_id  \
# 73538  periodicals/041-EWJ-1859-02-01-001-SINGLE/Pg06...    817      2814
# 73723  periodicals/041-EWJ-1860-03-01-001-SINGLE/Pg02...    828      2823
# 75301  periodicals/041-EWJ-1862-02-01-001-SINGLE/Pg02...    802      2851
# 71257  periodicals/041-EWJ-1858-09-01-001-SINGLE/Pg02...    791      2796
# 75831  periodicals/041-EWJ-1863-02-02-001-SINGLE/Pg05...    805      2858
# 73888  periodicals/041-EWJ-1860-04-01-001-SINGLE/Pg05...    805      2826
# 72679  periodicals/041-EWJ-1861-10-01-001-SINGLE/Pg07...    820      2836
# 71970  periodicals/041-EWJ-1860-05-01-001-SINGLE/Pg00...    793      2818
# 76257  periodicals/041-EWJ-1863-04-01-001-SINGLE/Pg04...    837      2865
# 74645  periodicals/041-EWJ-1861-04-01-001-SINGLE/Pg01...    806      2840
# 28889  periodicals/101-LDR-1852-04-24-001-SINGLE/Pg00...   1222      2964
# 40668  periodicals/101-LDR-1859-04-02-001-SINGLE/Pg02...   1351      3454
# 19698  periodicals/101-CLD-1854-09-09-001-SINGLE/Pg01...   1073      2410
# 25547  periodicals/101-CLD-1856-04-26-001-SINGLE/Pg01...   1126      2667
# 21548  periodicals/101-CLD-1859-01-08-001-SINGLE/Pg02...   1160      2581
# 32564  periodicals/101-LDR-1853-01-29-001-SINGLE/Pg02...   1265      3130
# 29714  periodicals/101-LDR-1856-06-28-001-SINGLE/Pg01...   1351      2992
# 20274  periodicals/101-CLD-1858-04-03-001-SINGLE/Pg01...   1082      2427
# 30091  periodicals/101-LDR-1856-07-26-001-SINGLE/Pg00...   1351      3005
# 25290  periodicals/041-CLD-1852-08-14-001-SINGLE/Pg01...   1294      2656
# 68680  periodicals/101-MRP-1822-10-02-PG001-SINGLE/Pg...   1027      3646
# 42617  periodicals/041-EMRP-1817-12-02-PG001-SINGLE/P...   1009      2786
# 62636  periodicals/101-MRP-1825-07-02-PG001-SINGLE/Pg...    997      3528
# 43445  periodicals/101-MRP-1834-06-02-PG001-SINGLE/Pg...    860      3681
# 60469  periodicals/101-MRP-1813-03-02-PG001-SINGLE/Pg...   1003      3491
# 57984  periodicals/101-MRP-1832-08-02-PG001-SINGLE/Pg...    887      3862
# 65750  periodicals/101-MRP-1837-02-01-PG001-SINGLE/Pg...    794      3584
# 64323  periodicals/101-MRP-1833-12-01-PG001-SINGLE/Pg...    677      3561
# 65845  periodicals/101-MRP-1837-06-01-PG001-SINGLE/Pg...    799      3585
# 42953  periodicals/101-MRP-1832-02-02-PG001-SINGLE/Pg...    908      3871
# 83     periodicals/101-NSS-1839-11-02-PG001/Pg002_qfH...   1535      6045
# 511    periodicals/101-NS2-1852-10-02-PG001-SINGLE/Pg...   1183      5081
# 13343  periodicals/101-NS2-1838-05-05-PG001-SINGLE/Pg...   1575      4686
# 10028  periodicals/101-NS3-1849-10-06-PG001-SINGLE/Pg...   1299      5560
# 2283   periodicals/101-NS3-1843-08-26-PG001-SINGLE/Pg...   1575      5291
# 16808  periodicals/101-NS2-1851-01-18-PG001-SINGLE/Pg...   1303      4951
# 7104   periodicals/101-NSS-1838-09-15-PG001/Pg003_N3q...   1567      5813
# 17057  periodicals/101-NS2-1851-04-26-PG001-SINGLE/Pg...   1267      4987
# 7979   periodicals/101-NSS-1839-12-28-PG001/Pg007_3To...   1523      6007
# 3694   periodicals/101-NSS-1851-08-09-PG001/Pg005_hgx...   1427      6160
# 84734  periodicals/099-TEC-1889-09-02-001-SINGLE/Pg05...   1014      4262
# 89162  periodicals/099-TEC-1886-03-01-001-SINGLE/Pg05...    995      4318
# 90766  periodicals/099-TEC-1890-02-01-001-SINGLE/Pg06...    883      4337
# 90593  periodicals/099-TEC-1890-09-15-001-SINGLE/Pg00...    918      4335
# 78049  periodicals/099-TEC-1880-09-15-001-SINGLE/Pg01...    902      4143
# 86135  periodicals/099-TEC-1889-12-06-001-SINGLE/Pg17...   1002      4280
# 96773  periodicals/041-TTEC-1888-12-31-001-SINGLE/Pg1...   1074      4413
# 79661  periodicals/099-TEC-1884-07-01-001-SINGLE/Pg05...    989      4176
# 86238  periodicals/099-TEC-1889-12-06-001-SINGLE/Pg27...   1002      4280
# 97470  periodicals/099-TEC-1889-01-15-001-SINGLE/Pg07...   1003      4259
# 71018  periodicals/041-TTW-1868-08-22-PG001-SINGLE/Pg...   1587      4566
# 69724  periodicals/041-TTW-1869-03-20-PG001-SINGLE/Pg...   1139      4427
# 70038  periodicals/041-TTW-1869-05-15-PG001-SINGLE/Pg...   1279      4461
# 70337  periodicals/041-TTW-1870-01-22-PG001-SINGLE_Re...   1801      4493
# 69683  periodicals/041-TTW-1869-10-30-PG001-SINGLE/Pg...   1155      4425
# 69736  periodicals/041-TTW-1869-03-20-PG001-SINGLE/Pg...   1139      4427
# 69183  periodicals/041-TTW-1869-06-19-PG001-SINGLE/Pg...   1113      4420
# 69151  periodicals/041-FTTW-1867-05-11-PG001-SINGLE_R...   1600      2933
# 70284  periodicals/041-TTW-1870-04-02-PG001-SINGLE/Pg...   1312      4484
# 70058  periodicals/041-TTW-1869-05-29-PG001-SINGLE_Re...   2044      4459
#
#        article_count  label  publication_id  issue_date  slug  \
# 73538              3    427              24  1859-02-01   ewj
# 73723              1     29              24  1860-03-01   ewj
# 75301              3    384              24  1862-02-01   ewj
# 71257              1     25              24  1858-09-01   ewj
# 75831              1    415              24  1863-02-02   ewj
# 73888              1    125              24  1860-04-01   ewj
# 72679              1    143              24  1861-10-01   ewj
# 71970              1    148              24  1860-05-01   ewj
# 76257              3    121              24  1863-04-01   ewj
# 74645              1     87              24  1861-04-01   ewj
# 28889              3    386              20  1852-04-24     l
# 40668              7    443              20  1859-04-02     l
# 19698              4   None              20  1854-09-09     l
# 25547              2   None              20  1856-04-26     l
# 21548              1   None              20  1859-01-08     l
# 32564              8    118              20  1853-01-29     l
# 29714              3    616              20  1856-06-28     l
# 20274              7   None              20  1858-04-03     l
# 30091              4    701              20  1856-07-26     l
# 25290              2   None              20  1852-08-14     l
# 68680              2    590              22  1822-10-02  mruc
# 42617              2    754              22  1817-12-02  mruc
# 62636              1    436              22  1825-07-02  mruc
# 43445              1    423              22  1834-06-02  mruc
# 60469              1    191              22  1813-03-02  mruc
# 57984              1    511              22  1832-08-02  mruc
# 65750              1     95              22  1837-02-01  mruc
# 64323              1    359              22  1833-12-01  mruc
# 65845              1    370              22  1837-06-01  mruc
# 42953              1     96              22  1832-02-02  mruc
# 83                 6      2              27  1839-11-02    ns
# 511               11     16              27  1852-10-02    ns
# 13343              5      2              27  1838-05-05    ns
# 10028             18      8              27  1849-10-06    ns
# 2283               4      7              27  1843-08-26    ns
# 16808             11      4              27  1851-01-18    ns
# 7104               6      3              27  1838-09-15    ns
# 17057             12      5              27  1851-04-26    ns
# 7979               9  unpag              27  1839-12-28    ns
# 3694              20      5              27  1851-08-09    ns
# 84734              1   1082              26  1889-09-02    pc
# 89162              2    253              26  1886-03-01    pc
# 90766              1     iv              26  1890-02-01    pc
# 90593              2   1115              26  1890-09-15    pc
# 78049              2    721              26  1880-09-15    pc
# 86135              1     27              26  1889-12-06    pc
# 96773              0    121              26  1888-12-31    pc
# 79661              3    658              26  1884-07-01    pc
# 86238              1   1725              26  1889-12-06    pc
# 97470              1     76              26  1889-01-15    pc
# 71018              6  unpag              19  1868-08-22     t
# 69724              6  unpag              19  1869-03-20     t
# 70038              1  unpag              19  1869-05-15     t
# 70337              9     34              19  1870-01-22     t
# 69683              0  unpag              19  1869-10-30     t
# 69736              7    131              19  1869-03-20     t
# 69183              4    266              19  1869-06-19     t
# 69151              1  unpag              19  1867-05-11     t
# 70284              1  unpag              19  1870-04-02     t
# 70058              0  unpag              19  1869-05-29     t
#
#                                                    title
# 73538                English Woman’s Journal (1858-1864)
# 73723                English Woman’s Journal (1858-1864)
# 75301                English Woman’s Journal (1858-1864)
# 71257                English Woman’s Journal (1858-1864)
# 75831                English Woman’s Journal (1858-1864)
# 73888                English Woman’s Journal (1858-1864)
# 72679                English Woman’s Journal (1858-1864)
# 71970                English Woman’s Journal (1858-1864)
# 76257                English Woman’s Journal (1858-1864)
# 74645                English Woman’s Journal (1858-1864)
# 28889                                 Leader (1850-1860)
# 40668                                 Leader (1850-1860)
# 19698                                 Leader (1850-1860)
# 25547                                 Leader (1850-1860)
# 21548                                 Leader (1850-1860)
# 32564                                 Leader (1850-1860)
# 29714                                 Leader (1850-1860)
# 20274                                 Leader (1850-1860)
# 30091                                 Leader (1850-1860)
# 25290                                 Leader (1850-1860)
# 68680  Monthly Repository (1806-1838) and Unitarian C...
# 42617  Monthly Repository (1806-1838) and Unitarian C...
# 62636  Monthly Repository (1806-1838) and Unitarian C...
# 43445  Monthly Repository (1806-1838) and Unitarian C...
# 60469  Monthly Repository (1806-1838) and Unitarian C...
# 57984  Monthly Repository (1806-1838) and Unitarian C...
# 65750  Monthly Repository (1806-1838) and Unitarian C...
# 64323  Monthly Repository (1806-1838) and Unitarian C...
# 65845  Monthly Repository (1806-1838) and Unitarian C...
# 42953  Monthly Repository (1806-1838) and Unitarian C...
# 83                             Northern Star (1837-1852)
# 511                            Northern Star (1837-1852)
# 13343                          Northern Star (1837-1852)
# 10028                          Northern Star (1837-1852)
# 2283                           Northern Star (1837-1852)
# 16808                          Northern Star (1837-1852)
# 7104                           Northern Star (1837-1852)
# 17057                          Northern Star (1837-1852)
# 7979                           Northern Star (1837-1852)
# 3694                           Northern Star (1837-1852)
# 84734                   Publishers’ Circular (1880-1890)
# 89162                   Publishers’ Circular (1880-1890)
# 90766                   Publishers’ Circular (1880-1890)
# 90593                   Publishers’ Circular (1880-1890)
# 78049                   Publishers’ Circular (1880-1890)
# 86135                   Publishers’ Circular (1880-1890)
# 96773                   Publishers’ Circular (1880-1890)
# 79661                   Publishers’ Circular (1880-1890)
# 86238                   Publishers’ Circular (1880-1890)
# 97470                   Publishers’ Circular (1880-1890)
# 71018                               Tomahawk (1867-1870)
# 69724                               Tomahawk (1867-1870)
# 70038                               Tomahawk (1867-1870)
# 70337                               Tomahawk (1867-1870)
# 69683                               Tomahawk (1867-1870)
# 69736                               Tomahawk (1867-1870)
# 69183                               Tomahawk (1867-1870)
# 69151                               Tomahawk (1867-1870)
# 70284                               Tomahawk (1867-1870)
# 70058                               Tomahawk (1867-1870)

# %%
df_list = []

for filename in os.listdir(directory):

    file_path = os.path.join(directory, filename)

    df = pd.read_parquet(file_path)
    
    df = df.loc[(df['total_tokens']>=100) & (df['total_tokens']<=3000) & (df['symbol_fract']<0.3) & 
                (df['article_type_id']!=3), :]
    df.drop(columns=[ 'continuation_from_id', 'continuation_to_id'], inplace=True)

    df_list.append(df)

df = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# Create the sampling function

# %%
def sample_data(df, num_articles = 20, num_adverts = 25, random_seed = 1842):

    np.random.seed(random_seed)

    # Sample 20 when article_type == 1
    sampled_df_1 = df[df['article_type_id'] == 1].groupby(['article_type_id', 'publication_id']).sample(n=num_articles, replace=False)

    # Sample 25 when article_type == 2
    sampled_df_2 = df[df['article_type_id'] == 2].groupby(['article_type_id', 'publication_id']).sample(n=num_adverts, replace=False)

    # Concatenate the sampled DataFrames
    test_data = pd.concat([sampled_df_1, sampled_df_2], ignore_index=True)

    # Reset index
    test_data.reset_index(drop=True, inplace=True)

    return test_data

# %% [markdown]
# Generate the different datasets, subsetting each time so there is no overlap. Random seed ensures reproducibility

# %%
test_data = sample_data(df,  num_articles = 20, num_adverts = 25, random_seed = 1842)

#this is tiny as I have to transcribe this myself and is just used for tuning the prompt
dev_data = sample_data(df.loc[~df['id'].isin(test_data.id),:], num_articles = 2, num_adverts = 3, random_seed = 1842)

#This is used for creating the silver label train set with the final prompt on gpt-4/opus
train_data = sample_data(df.loc[~df['id'].isin(test_data.id.to_list() +dev_data.id.to_list()),:], num_articles = 100, num_adverts = 125, random_seed = 1842)

test_data.to_csv('./data/test_data_raw.csv')
dev_data.to_csv('./data/dev_data_raw.csv')
train_data.to_csv('./data/train_data_raw.csv')
del df

# %% [markdown]
# # Prepare test set for transcribing
#
# The test set needs to be cleaned up to make it easier to be used for transcribing. This includes subsetting the columns, and getting the name of the file so that it can be loaded. The file names come from the database and seem a bit annoying as there doesn't seem to be an obvious pattern

# %%
folder2id_df = pd.DataFrame([{'folder':'English_Womans_Journal_issue_PDF_files', 'publication_id':24},
 {'folder':'Leader_issue_PDF_files/Leader_issue_PDF_files', 'publication_id':20},
 {'folder':'Monthly_Repository_issue_PDF_files', 'publication_id':22},
 {'folder':'Northern_Star_issue_PDF_files', 'publication_id':27},
 {'folder':'Publishers_Circular_issue_PDF_files', 'publication_id':26},
 {'folder':'Tomahawk_issue_PDF_files/Tomahawk_issue_PDF_files', 'publication_id':19}])

# %%
#create folders of the pdfs for the test and dev set

temp = test_data.merge(folder2id_df, on = 'publication_id')

temp['pdf_path'] =temp.apply(lambda row: find_pdf_path(image_path, row['folder'],  row['issue_date'].strftime('%Y-%m-%d')), axis=1)

process_pdfs(temp, output_folder="data/test_pdfs_for_transcription", 1)

temp[['content_html', 'file_name', 'total_tokens', 'issue_date', 'page_number', 'pdf_path','site_address']].to_csv('./data/test_data_transcription.csv')


temp = dev_data.merge(folder2id_df, on = 'publication_id')

temp['pdf_path'] =temp.apply(lambda row: find_pdf_path(image_path, row['folder'],  row['issue_date'].strftime('%Y-%m-%d')), axis=1)

process_pdfs(temp, output_folder="data/dev_pdfs_for_transcription", 1)

# %%
temp[['content_html', 'file_name', 'total_tokens', 'issue_date', 'page_number', 'pdf_path','site_address']].to_csv('./data/dev_data_transcription.csv')

# %%
test_data['total_tokens'].sum()*0.8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 test_data['total_tokens'].sum()*0.8
#
# NameError: name 'test_data' is not defined
